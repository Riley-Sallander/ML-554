# %% [markdown]
# # GSB 544 - Lab One
#
# ### Task 1
#
# #### 1)
#
# ###### X = Income
# ###### Y = Life Expectancy
# ###### Size = Population
# ###### color = Country
#
# #### 2)

# %%
import pandas as pd 
dfQ1 = pd.read_csv("/Users/rileysallander/Desktop/ML/ML554/Data/q1data.csv")

dfQ1.head()
# Out:
#     income  life_exp  population  ...               six_regions       eight_regions           world_bank_region
# 0   1910.0      61.0  29200000.0  ...                south_asia           asia_west                  South Asia
# 1  11100.0      78.1   2950000.0  ...       europe_central_asia         europe_east       Europe & Central Asia
# 2  11100.0      74.7  36000000.0  ...  middle_east_north_africa        africa_north  Middle East & North Africa
# 3  46900.0      81.9     84500.0  ...       europe_central_asia         europe_west       Europe & Central Asia
# 4   7680.0      60.8  23400000.0  ...        sub_saharan_africa  africa_sub_saharan          Sub-Saharan Africa
#
# [5 rows x 9 columns]

# %% [markdown]
# #### 3)

# %%
from plotnine import geom_point, ggplot, aes, labs

(ggplot(dfQ1,
aes(
  x = "income",
  y = "life_exp",
  color = "eight_regions",
  size = "population"
))
+ geom_point()
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 4 rows containing missing values.
